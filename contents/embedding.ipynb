# %%
# %pip install -Uq langchain langchain-core langchain-ollama
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama.embeddings import OllamaEmbeddings

# nomic-embed-text-v2-moe
model = OllamaEmbeddings(
    model="nomic-embed-text-v2-moe"
)

# embed_documents()
# embed_query()

vector = model.embed_query("비행기")

print(len(vector))
# Out:
# 768

# %%
docs = [ "안녕하세요!", "반갑습니다!" ]

vectors = model.embed_documents(docs)

print(vectors[0][1:5], vectors[1][1:5])
# Out:
# [-0.0086627435, 0.03062954, -0.042884573, 0.030770285] [-0.005546094, 0.006124389, -0.009071282, 0.0055181915]
