# %%
from langchain_community.document_loaders import CSVLoader

csv_loader = CSVLoader(
    file_path="./libs/002/iris.csv",
    encoding="utf-8"
)

csv_docs = csv_loader.load()

csv_doc = csv_docs[:5]

for row in csv_doc:
    print(type(row))
    print(row.metadata)
    print(row.page_content)
# Out:
# <class 'langchain_core.documents.base.Document'>
# {'source': './libs/002/iris.csv', 'row': 0}
# Id: 1
# SepalLengthCm: 5.1
# SepalWidthCm: 3.5
# PetalLengthCm: 1.4
# PetalWidthCm: 0.2
# Species: Iris-setosa
# <class 'langchain_core.documents.base.Document'>
# {'source': './libs/002/iris.csv', 'row': 1}
# Id: 2
# SepalLengthCm: 4.9
# SepalWidthCm: 3.0
# PetalLengthCm: 1.4
# PetalWidthCm: 0.2
# Species: Iris-setosa
# <class 'langchain_core.documents.base.Document'>
# {'source': './libs/002/iris.csv', 'row': 2}
# Id: 3
# SepalLengthCm: 4.7
# SepalWidthCm: 3.2
# PetalLengthCm: 1.3
# PetalWidthCm: 0.2
# Species: Iris-setosa
# <class 'langchain_core.documents.base.Document'>
# {'source': './libs/002/iris.csv', 'row': 3}
# Id: 4
# SepalLengthCm: 4.6
# SepalWidthCm: 3.1
# PetalLengthCm: 1.5
# PetalWidthCm: 0.2
# Species: Iris-setosa
# <class 'langchain_core.documents.base.Document'>
# {'source': './libs/002/iris.csv', 'row': 4}
# Id: 5
# SepalLengthCm: 5.0
# SepalWidthCm: 3.6
# ...
