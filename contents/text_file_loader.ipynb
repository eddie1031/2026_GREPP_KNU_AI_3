# %%
# %pip install -Uq langchain-community
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document

loader = TextLoader(
    file_path="libs/001/sample1.txt",
    encoding="utf-8"
)

docs = loader.load()

doc: Document = docs[0]

print(doc.metadata)

print(len(doc.page_content))

print(doc.page_content[:35])
# Out:
# {'source': 'libs/001/sample1.txt'}
# 1308
# ## 1. LangChain이란
#
# LangChain은 2022년

# %%
# %pip install -Uq tqdm
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

txt_file_loader = DirectoryLoader(
    path="./libs",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={
        "encoding": "utf-8"
    },
    silent_errors=True,
    show_progress=True
)

text_docs = txt_file_loader.load()

for text_doc in text_docs:
    print(text_doc.metadata)
    print(text_doc.page_content[:35])
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 1133.29it/s]
# {'source': 'libs/001/sample1.txt'}
# ## 1. LangChain이란
#
# LangChain은 2022년
# {'source': 'libs/001/sample2.txt'}
# ## 1. LangChain이란
#
# LangChain은 2022년
